"cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.19237112998962402, "copy": 0.09160137176513672, "kernel": 0.27686500549316406}},
    {"prefill_length": 8192, "breakdown_times": {"LlamaSdpaAttention.forward": 1.8592329025268555, "qkv_proj": 0.8830931186676025, "rotary_emb": 0.288989782333374, "cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.1909959316253662, "copy": 0.09155845642089844, "kernel": 0.3875157833099365}},
    {"prefill_length": 16384, "breakdown_times": {"LlamaSdpaAttention.forward": 2.0372090339660645, "qkv_proj": 0.879075288772583, "rotary_emb": 0.2894465923309326, "cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.1911017894744873, "copy": 0.09186339378356934, "kernel": 0.5684137344360352}},
    {"prefill_length": 32768, "breakdown_times": {"LlamaSdpaAttention.forward": 2.371843099594116, "qkv_proj": 0.8902974128723145, "rotary_emb": 0.2884526252746582, "cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.19354891777038574, "copy": 0.09234476089477539, "kernel": 0.8896691799163818}}
]


# Convert data to DataFrames
baseline = pd.DataFrame([{**{"prefill_length": d["prefill_length"]}, **d["breakdown_times"]} for d in baseline])
ours = pd.DataFrame([{**{"prefill_length": d["prefill_length"]}, **d["breakdown_times"]} for d in ours])
ours = ours.drop(columns=['cat', 'repeat_kv', 'causal_mask', 'contiguous', 'sdpa'])

# Move 'o_proj' to the last position
cols = [col for col in ours.columns if col != 'o_proj'] + ['o_proj']
ours = ours[cols]

# calculate others
# baseline['others'] = baseline['LlamaSdpaAttention.forward'] - baseline.drop(columns=['prefill_length', 'LlamaSdpaAttention.forward', 'others'], errors='ignore').sum(axis=1)
# ours['others'] = ours['LlamaSdpaAttention.forward'] - ours.drop(columns=['prefill_length', 'LlamaSdpaAttention.forward', 'others'], errors='ignore').sum(axis=1)

# %%
baseline
# Out:
#    prefill_length  LlamaSdpaAttention.forward  qkv_proj  rotary_emb       cat  \
# 0            1024                    1.750753  0.884183    0.289873  0.166335
# 1            2048                    1.915361  0.882670    0.289572  0.287740
# 2            4096                    2.264262  0.886703    0.291780  0.533431
# 3            8192                    2.948097  0.882272    0.290084  1.030863
# 4           16384                    4.339188  0.881932    0.291330  2.037999
# 5           32768                    7.163238  0.884285    0.289795  4.094153
#
#    repeat_kv  causal_mask  contiguous      sdpa    o_proj
# 0   0.013942     0.009940    0.017161  0.148688  0.204962
# 1   0.014027     0.009958    0.017280  0.194214  0.204294
# 2   0.014102     0.009934    0.017083  0.290837  0.204648
# 3   0.014277     0.009968    0.017089  0.482184  0.205615
# 4   0.014601     0.009941    0.017098  0.864549  0.205950
# 5   0.015137     0.009995    0.017150  1.629465  0.207397

# %%
ours
# Out:
#    prefill_length  LlamaSdpaAttention.forward  qkv_proj  rotary_emb      copy  \
# 0            1024                    1.668392  0.877325    0.293360  0.092194
# 1            2048                    1.688328  0.878791    0.290971  0.091542
# 2            4096                    1.747103  0.877785    0.291511  0.091601
# 3            8192                    1.859233  0.883093    0.288990  0.091558
# 4           16384                    2.037209  0.879075    0.289447  0.091863
# 5           32768                    2.371843  0.890297    0.288453  0.092345
#
#      kernel    o_proj
# 0  0.193854  0.194276
"cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.19265413284301758, "copy": 0.09245705604553223, "kernel": 0.25017261505126953}},
    {"prefill_length": 8192, "breakdown_times": {"LlamaSdpaAttention.forward": 1.9035539627075195, "qkv_proj": 0.9499404430389404, "rotary_emb": 0.29401230812072754, "cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.19172167778015137, "copy": 0.09319925308227539, "kernel": 0.35706090927124023}},
    {"prefill_length": 16384, "breakdown_times": {"LlamaSdpaAttention.forward": 2.1009421348571777, "qkv_proj": 0.9481940269470215, "rotary_emb": 0.29143428802490234, "cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.19318294525146484, "copy": 0.09256219863891602, "kernel": 0.5581142902374268}},
    {"prefill_length": 32768, "breakdown_times": {"LlamaSdpaAttention.forward": 2.488361120223999, "qkv_proj": 0.9499082565307617, "rotary_emb": 0.2905139923095703, "cat": 0, "repeat_kv": 0, "causal_mask": 0, "contiguous": 0, "sdpa": 0, "o_proj": 0.19234561920166016, "copy": 0.09227275848388672, "kernel": 0.9458231925964355}}
]

# Convert data to DataFrames
baseline = pd.DataFrame([{**{"prefill_length": d["prefill_length"]}, **d["breakdown_times"]} for d in baseline])
ours = pd.DataFrame([{**{"prefill_length": d["prefill_length"]}, **d["breakdown_times"]} for d in ours])
ours = ours.drop(columns=['cat', 'repeat_kv', 'causal_mask', 'contiguous', 'sdpa'])

# Move 'o_proj' to the last position
cols = [col for col in ours.columns if col != 'o_proj'] + ['o_proj']
ours = ours[cols]

# %%
baseline
# Out:
#    prefill_length  LlamaSdpaAttention.forward  qkv_proj  rotary_emb       cat  \
# 0            1024                    1.914792  0.959513    0.292291  0.085541
# 1            2048                    2.019291  0.952741    0.291891  0.108572
# 2            4096                    2.297999  0.944206    0.297741  0.166980
# 3            8192                    2.931476  0.949834    0.291043  0.287784
# 4           16384                    4.645864  0.948769    0.291756  0.536925
# 5           32768                    7.582024  0.949155    0.292251  1.030377
#
#    repeat_kv  causal_mask  contiguous      sdpa    o_proj
# 0   0.177989     0.011178    0.018099  0.145445  0.207406
# 1   0.218604     0.011158    0.018046  0.194032  0.204859
# 2   0.344105     0.011421    0.018180  0.291777  0.206131
# 3   0.671739     0.011279    0.017992  0.479552  0.205144
# 4   1.752269     0.011642    0.018202  0.862968  0.206044
# 5   3.426763     0.012036    0.018507  1.628677  0.206836

# %%
ours
# Out:
#    prefill_length  LlamaSdpaAttention.forward  qkv_proj  rotary_emb      copy  \
# 0            1024                    1.728402  0.947302    0.291751  0.093601
# 1            2048                    1.754611  0.953004    0.290987  0.092422
# 2            4096                    1.793745  0.949941    0.290971  0.092457
# 3            8192                    1.903554  0.949940    0.294012  0.093199
# 4           16384                    2.100942  0.948194    0.291434  0.092562
# 5           32768                    2.488361  0.949908    0.290514  0.092273
#
#      kernel    o_proj
# 0  0.182148  0.195929
# 1  0.205045  0.195529
# 2  0.250173  0.192654
# 3  0.357061  0.191722
# 4  0.558114  0.193183
# 5  0.945823  0.192346
